# %%
import nltk
#nltk.download()

# %%
from urllib.request import Request, urlopen

# %%
link = Request('http://ultimosegundo.ig.com.br/politica/2017-04-25/reforma-da-previdencia.html',headers={'User-Agent': 'Mozilla/5.0'})

pagina = urlopen(link).read().decode('utf-8', 'ignore')

from bs4 import BeautifulSoup
soup = BeautifulSoup(pagina, "html")
texto = soup.find(id="noticia").text

# %%
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize

# %%
# Dividindo o texto em palavras e em sentenças
sentencas = sent_tokenize(texto)
palavras = word_tokenize(texto.lower())

for i in range(10):
    print(palavras[i])
# Out:
# lúcio
# bernardo
# junior/câmara
# dos
# deputados
# -
# 19.4.17
# deputados
# discutem
# na

# %%
# Lidando com stopwords
from nltk.corpus import stopwords
from string import punctuation

stopwords = set(stopwords.words('portuguese') + list(punctuation))
palavras_sem_stopwords = [palavra for palavra in palavras if palavra not in stopwords]

#stopwords
palavras_sem_stopwords
# Out:
# ['lúcio',
#  'bernardo',
#  'junior/câmara',
#  'deputados',
#  '19.4.17',
#  'deputados',
#  'discutem',
#  'comissão',
#  'reforma',
#  'previdência',
#  'gravata',
#  'roxa',
#  'presidente',
#  'colegiado',
#  'carlos',
#  'marun',
#  'comissão',
#  'especial',
#  'analisa',
#  'proposta',
#  'reforma',
#  'previdência',
#  'câmara',
#  'deputados',
#  'inicia',
#  'tarde',
#  'desta',
#  'terça-feira',
#  '25',
#  'discussão',
#  'relatório',
#  'apresentado',
#  'semana',
#  'passada',
#  'relator',
#  'deputado',
#  'arthur',
#  'maia',
#  'pps-ba',
#  'fechar',
#  'acordo',
#  'parlamentares',
#  'oposição',
#  'tentavam',
#  'obstruir',
#  'sessão',
#  'leitura',
#  'parecer',
#  'relator',
#  'presidente',
#  'comissão',
#  'reforma',
#  'previdência',
#  'deputado',
#  'carlos',
#  'marun',
#  'pmdb-ms',
#  'designou',
#  'todas',
#  'reuniões',
#  'desta',
#  'semana',
#  'discutir',
#  'relatório',
#  'apresentar',
#  'pedido',
#  'vista',
#  'acordo',
#  'oposição',
#  'ainda',
#  'definiu',
#  'votação',
#  'relatório',
#  'membros',
#  'comissão',
#  'deve',
#  'ocorrer',
#  'próxima',
#  'semana',
#  'dia',
#  '2',
#  'maio',
#  'partir',
#  'dia',
#  '8',
#  'relatório',
#  'estaria',
#  'pronto',
#  'ser',
#  'votado',
#  'plenário',
#  'câmara',
#  'deputados',
#  'aconteça',
#  'equipe',
#  'governo',
#  'temer',
#  'segue',
#  'atuando',
#  'conquistar',
#  'votos',
#  'necessários',
#  'aprovar',
#  'mudanças',
#  'regras',
#  'aposentadoria',
#  'reduzir',
#  'resistência',
#  'proposta',
#  'planalto',
#  'aceitou',
#  'flexibilizar',
#  'alguns',
#  'pontos',
#  'texto',
#  'original',
#  'embora',
#  'maior',
#  'parte',
#  'ideias',
#  'iniciais',
#  'sido',
#  'preservada',
#  'relatório',
#  'arthur',
#  'maia',
#  'fixa',
#  'idade',
#  'mínima',
#  'aposentadoria',
#  '62',
#  'anos',
#  'mulheres',
#  '65',
#  'anos',
#  'homens',
#  'após',
#  'período',
#  'transição',
#  '20',
#  'anos',
#  'aumento',
#  'progressivo',
#  'começando',
#  '53',
#  '55',
#  'anos',
#  'respectivamente',
#  'data',
#  'promulgação',
#  'emenda',
#  'aposentadoria',
#  'tempo',
#  'contribuição',
#  'segurado',
#  'calcular',
#  'quanto',
#  'falta',
#  'aposentar',
#  'regras',
#  'atuais',
#  '–',
#  '35',
#  'anos',
#  'homem',
#  '30',
#  'anos',
#  'mulher',
#  '–',
#  'adicionar',
#  'pedágio',
#  '30',
#  'aí',
#  'checar',
#  'tabela',
#  'aumento',
#  'progressivo',
#  'idade',
#  'começa',
#  '53',
#  'anos',
#  'mulher',
#  '55',
#  'anos',
#  'homem',
#  'verificar',
#  'idade',
#  'mínima',
#  'vai',
#  'vigorar',
#  'após',
#  'tempo',
#  'tabela',
#  'idade',
#  'sobe',
#  'ano',
#  'cada',
#  'dois',
#  'anos',
#  'partir',
#  '2020.',
#  'portanto',
#  '65',
#  'anos',
#  'homem',
#  'cobrados',
#  'partir',
#  '2038.',
#  'leia',
#  'após',
#  'assalto',
#  'milionário',
#  'paraguai',
#  'oito',
#  'suspeitos',
#  'presos',
#  'paraná',
#  'cronograma',
#  'líder',
#  'governo',
#  'congresso',
#  'deputado',
#  'andré',
#  'moura',
#  'psc',
#  'afirmou',
#  'tv',
#  'brasil',
#  'cabe',
#  'mudanças',
#  'proposta',
#  'reforma',
#  'previdência',
#  'segundo',
#  'moura',
#  'modificações',
#  'solicitadas',
#  'base',
#  'feitas',
#  'texto',
#  'ser',
#  'trabalhado',
#  'aprovação',
#  'apresentado',
#  'relator',
#  'comissão',
#  'especial',
#  '``',
#  'entendimento',
#  'governo',
#  'agora',
#  'esperar',
#  'base',
#  'atendida',
#  'possa',
#  'votar',
#  'texto',
#  'apresentado',
#  'relator',
#  '”',
#  'disse',
#  'sobre',
#  'possibilidade',
#  'adiamento',
#  'data',
#  'votação',
#  'proposta',
#  'líder',
#  'garantiu',
#  'cronograma',
#  'mantido',
#  'prorrogado',
#  '``',
#  'semana',
#  'cronograma',
#  'estabelecido',
#  'cumprido',
#  "''",
#  'destacou',
#  'líder',
#  'reiterou',
#  'plenário',
#  'deve',
#  'votar',
#  'reforma',
#  'trabalhista',
#  'nesta',
#  'semana',
#  'próxima',
#  'previdência',
#  '“',
#  'nesta',
#  'terça',
#  'devemos',
#  'concluir',
#  'votação',
#  'recuperação',
#  'fiscal',
#  'estados',
#  'plenário',
#  'votar',
#  'reforma',
#  'trabalhista',
#  'amanhã',
#  '27',
#  'comissão',
#  'especial',
#  'quarta-feira',
#  '28',
#  'votar',
#  'plenário',
#  'próxima',
#  'semana',
#  'após',
#  'feriado',
#  'votar',
#  'reforma',
#  'previdência',
#  'comissão',
#  'especial',
#  'logo',
#  'seguida',
#  'plenário',
#  '”',
#  'afirmou',
#  'relatório',
#  'ainda',
#  'pode',
#  'ser',
#  'alterado',
#  'durante',
#  'discussões',
#  'câmara',
#  'tornar',
#  'lei',
#  'proposta',
#  'reforma',
#  'previdência',
#  'precisa',
#  'após',
#  'ser',
#  'aprovada',
#  'comissão',
#  'especial',
#  'passar',
#  'votação',
#  'dois',
#  'turnos',
#  'plenário',
#  'câmara',
#  'receber',
#  'aval',
#  'senado',
#  'caso',
#  'senadores',
#  'modifiquem',
#  'texto',
#  'projeto',
#  'precisará',
#  'retornar',
#  'mãos',
#  'deputados',
#  'leia',
#  'lava',
#  'jato',
#  'stj',
#  'recebe',
#  'pedido',
#  'investigação',
#  'contra',
#  'governadores',
#  '*com',
#  'informações',
#  'agência',
#  'brasil',
#  'agência',
#  'câmara']
